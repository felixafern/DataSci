# %% [markdown]
# # U.S. Medical Insurance Costs

# %%
import pandas as pd

# %%
path = '/Users/felix/ml/Codeacademy/python-portfolio-project-starter-files'

# %%
insurance = pd.read_csv(f'{path}/insurance.csv')

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# 7 columns, no missing data

# %%
# 1 Find out the average age of the patients in the dataset.
# 2 Analyze where a majority of the individuals are from.
# 3 Look at the different costs between smokers vs. non-smokers.
# 4 Figure out what the average age is for someone who has at least one child in this dataset.

# %%
# 1
def mean_ages(csv):
    return sum(csv['age'])/len(csv['age'])

# %%
mean_ages(insurance)
# Out:
# 39.20702541106129

# %%
# 2 

insurance.shape
# Out:
# (1338, 7)

# %%
insurance['region'].value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
region_freq = [insurance['region'].value_counts()[0], 
              insurance['region'].value_counts()[1], 
              insurance['region'].value_counts()[2], 
              insurance['region'].value_counts()[3]]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

labels = ['southeast', 'northwest', 'southwest', 'northeast']
data = region_freq
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Individuals per region')
plt.bar(labels, data)
# Out:
# <BarContainer object of 4 artists>

# %%
# Pretty balanced. Highest population in southeast

# %%
insurance['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
smokers = insurance.copy()

# %%
smokers.drop(columns= ['children'], inplace=True)

# %%
def cost_of_smoking(csv):
    smokeless = []
    smoker = []
    for row in csv:
        if 'yes' in csv['smoker']:
            smoker.append(csv['charges'])
        else:
            smokeless.append(csv['charges'])
        return smokeless), s

# %%
cost_of_smoking(smokers)
# Out:
# (0       16884.92400
#  1        1725.55230
#  2        4449.46200
#  3       21984.47061
#  4        3866.85520
#  5        3756.62160
#  6        8240.58960
#  7        7281.50560
#  8        6406.41070
#  9       28923.13692
#  10       2721.32080
#  11      27808.72510
#  12       1826.84300
#  13      11090.71780
#  14      39611.75770
#  15       1837.23700
#  16      10797.33620
#  17       2395.17155
#  18      10602.38500
#  19      36837.46700
#  20      13228.84695
#  21       4149.73600
#  22       1137.01100
#  23      37701.87680
#  24       6203.90175
#  25      14001.13380
#  26      14451.83515
#  27      12268.63225
#  28       2775.19215
#  29      38711.00000
#             ...
#  1308    33900.65300
#  1309     6875.96100
#  1310     6940.90985
#  1311     4571.41305
#  1312     4536.25900
#  1313    36397.57600
#  1314    18765.87545
#  1315    11272.33139
#  1316     1731.67700
#  1317     1163.46270
#  1318    19496.71917
#  1319     7201.70085
# ...
